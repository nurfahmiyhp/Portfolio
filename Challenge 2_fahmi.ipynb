# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sr = pd.read_csv("final-fix.csv")

# %%
sr
# Out:
#       Unnamed: 0    country  year     sex          age  suicides_no  \
# 0              0  Argentina  2006    male    75+ years          246
# 1              1  Argentina  2006    male  15-24 years          656
# 2              2  Argentina  2006    male  55-74 years          487
# 3              3  Argentina  2006    male  25-34 years          483
# 4              4  Argentina  2006    male  35-54 years          585
# ...          ...        ...   ...     ...          ...          ...
# 6439        6439    Uruguay  2015  female  25-34 years           23
# 6440        6440    Uruguay  2015  female  35-54 years           38
# 6441        6441    Uruguay  2015  female  15-24 years           17
# 6442        6442    Uruguay  2015    male   5-14 years            3
# 6443        6443    Uruguay  2015  female   5-14 years            2
#
#       population  suicides/100k pop  gdp_for_year ($)  gdp_per_capita ($)  \
# 0         620010              39.68      233000000000                6475
# ...

# %%
import seaborn as sns

male_population = sr.loc[sr.loc[:, 'sex']=='male',:]
female_population = sr.loc[sr.loc[:, 'sex']=='female',:]

plt.figure(figsize=(8,4))

lp_male = sns.lineplot(x = 'year' , y = 'suicides_no' , data = male_population)
lp_female = sns.lineplot(x = 'year' , y = 'suicides_no' , data = female_population)
leg1 = plt.legend(['Males','Females'])

# %%
plt.figure(figsize=(20,5))
sns.barplot(x = "country", y = "suicides_no", hue = "age", data = sr)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.scatterplot(x = "country", y = "suicides_no", hue = "age", data = sr, estimator=max)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.scatterplot(x = "country", y = "suicides_no", hue = "age", data = sr, estimator=max)
plt.xticks(rotation=90)
plt.legend(['5-14 years','15-24 years','25-34 years','35-54 years','55-74 years','75+ years'])
plt.show()

# %%
age_pop0 = sr.loc[sr.loc[:, 'age']=='5-14 years',:]
age_pop1 = sr.loc[sr.loc[:, 'age']=='15-24 years',:]
age_pop2 = sr.loc[sr.loc[:, 'age']=='25-34 years',:]
age_pop3 = sr.loc[sr.loc[:, 'age']=='35-54 years',:]
age_pop4 = sr.loc[sr.loc[:, 'age']=='55-74 years',:]
age_pop5 = sr.loc[sr.loc[:, 'age']=='75+ years',:]

plt.figure(figsize=(20,6))

lp_pop0 = sns.scatterplot(x = 'country' , y = 'suicides_no' , data = age_pop0)
lp_pop1 = sns.scatterplot(x = 'country' , y = 'suicides_no' , data = age_pop1)
lp_pop2 = sns.scatterplot(x = 'country' , y = 'suicides_no' , data = age_pop2)
lp_pop3 = sns.scatterplot(x = 'country' , y = 'suicides_no' , data = age_pop3)
lp_pop4 = sns.scatterplot(x = 'country' , y = 'suicides_no' , data = age_pop4)
lp_pop5 = sns.scatterplot(x = 'country' , y = 'suicides_no' , data = age_pop5)
leg1 = plt.legend(['5-14 years','15-24 years','25-34 years','35-54 years','55-74 years','75+ years'], prop={"size":20})

plt.xticks(rotation=90)

plt.show()
